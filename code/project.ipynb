# %%
from ultralytics import YOLO
 
model = YOLO('yolov8n.pt')

# %%
# Training.
results = model.train(
   data=r'/Users/samradny/Desktop/Road-Condition-Detection-System-main/Pothole detect yolo.v1i.yolov8-obb/data.yaml',
   imgsz=640,
   epochs=30,
   batch=32,
   name='yolov8n_custom_pholoe')
# Out:
# Ultralytics 8.3.27 🚀 Python-3.9.6 torch-2.5.0 CPU (Apple M2)
# ...

# %%
# !yolo task=classify mode=val model='/Users/samradny/.pyenv/runs/detect/yolov8n_custom_pholoe36/weights/best.pt' data='/Users/samradny/Desktop/Road-Condition-Detection-System-main/Pothole detect yolo.v1i.yolov8-obb/data.yaml'
# Out:
# pyenv: yolo: command not found
#
# The `yolo' command exists in these Python versions:
#   3.9.6
#   3.9.6/envs/myenv-3.9.6
#   myenv-3.9.6
#
# Note: See 'pyenv help global' for tips on allowing both
#       python2 and python3 to be found.

# %%
model = YOLO("/Users/samradny/.pyenv/runs/detect/yolov8n_custom_pholoe4/weights/best.pt")  # load a custom model
    
# Validate the model
results = model.val()
# Out:
# Ultralytics 8.3.27 🚀 Python-3.9.6 torch-2.5.0 CPU (Apple M2)
# Model summary (fused): 168 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /Users/samradny/Desktop/Road-Condition-Detection-System-main/Potho
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         34         67      0.906      0.414      0.435      0.311
#                Pothole         32         63      0.813      0.828      0.861       0.62
#                 object          2          4          1          0    0.00888    0.00266
# Speed: 1.1ms preprocess, 150.3ms inference, 0.0ms loss, 7.1ms postprocess per image
# Results saved to /Users/samradny/.pyenv/runs/detect/val14

# %%
from IPython.display import display, Image

# %%
# %cd /Users/samradny
Image(filename='Desktop/Road-Condition-Detection-System-main/Pothole detect yolo.v1i.yolov8-obb/confusion_matrix.png', height=600)
# Out:
# /Users/samradny

# %%
Image(filename='Desktop/Road-Condition-Detection-System-main/Pothole detect yolo.v1i.yolov8-obb/results.png', height=600)

# %%
Image(filename='Desktop/Road-Condition-Detection-System-main/Pothole detect yolo.v1i.yolov8-obb/train_batch161.jpeg', height=600)

# %%
# !yolo task=classify mode=predict model='/Users/samradny/.pyenv/runs/detect/yolov8n_custom_pholoe4/weights/best.pt' conf=0.35 source='2.mp4'
# Out:
# pyenv: yolo: command not found
#
# The `yolo' command exists in these Python versions:
#   3.9.6
#   3.9.6/envs/myenv-3.9.6
#   myenv-3.9.6
#
# Note: See 'pyenv help global' for tips on allowing both
#       python2 and python3 to be found.

# %%
from ultralytics import YOLO
import cv2

# Load the trained YOLOv8 model for road damage detection
model = YOLO("/Users/samradny/.pyenv/runs/detect/yolov8n_custom_pholoe4/weights/best.pt")  # Update this with the correct path to your trained model

# Open a video capture object (0 for webcam or provide video file path)
cap = cv2.VideoCapture(0)

# Check if the video capture object has been initialized
if not cap.isOpened():
    print("Error: Could not open video source.")
    exit()

# Real-time video stream
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    if not ret:
        print("Error: Failed to capture frame.")
        break

    # Perform YOLOv8 detection on the current frame
    results = model(frame)
    
    # Visualize results on the frame
    annotated_frame = results[0].plot()

    # Display the resulting frame with detections
    cv2.imshow('Road Damage Detection', annotated_frame)

    # Press 'q' to quit the video stream
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything is done, release the capture and close windows
cap.release()
cv2.destroyAllWindows()
y
# Out:
# 0: 384x640 1 Pothole, 44.9ms
# Speed: 1.5ms preprocess, 44.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.5ms
# Speed: 2.2ms preprocess, 51.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.5ms
# Speed: 1.3ms preprocess, 47.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.2ms
# Speed: 1.2ms preprocess, 51.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.3ms
# Speed: 1.1ms preprocess, 45.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Pothole, 88.1ms
# Speed: 2.2ms preprocess, 88.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.5ms
# ...

# %%
import cv2
from ultralytics import YOLO

# Load your custom YOLO model (replace with the actual path to your model)
model = YOLO("/Users/samradny/.pyenv/runs/detect/yolov8n_custom_pholoe4/weights/best.pt")

# URL for Elgato Camera Hub (replace with actual camera feed URL)
camera_url = 'http://192.168.1.225:8080/video'  # Replace x with each of the IP addresses
  # Replace with your Elgato camera IP

# Open a connection to the camera feed
cap = cv2.VideoCapture(camera_url)

if not cap.isOpened():
    print("Error: Unable to open camera feed.")
    exit()

while True:
    # Read frames from the camera
    ret, frame = cap.read()

    if not ret:
        print("Error: Failed to capture image.")
        break

    # Perform YOLO detection on the frame
    results = model(frame)

    # Loop through detections and draw bounding boxes for potholes
    for result in results:
        for box in result.boxes:
            # Get the label for the detection (e.g., 'pothole' in your case)
            label = result.names[int(box.cls)]

            # If the label is 'pothole', process the detection
            if label == 'pothole':
                x1, y1, x2, y2 = map(int, box.xyxy[0])  # Extract bounding box coordinates
                confidence = box.conf  # Confidence score

                # Draw the bounding box and label on the frame
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, f"{label} {confidence:.2f}", (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # Display the frame with detections
    cv2.imshow('YOLO Pothole Detection', frame)

    # Exit on pressing 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close all windows
cap.release()
cv2.destroyAllWindows()
